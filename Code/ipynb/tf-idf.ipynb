# %%
# ============================================================
# 📦 IMPORT LIBRARY DAN LOAD DATASET
# ============================================================

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt

# Konfigurasi visual
plt.style.use("seaborn-v0_8-muted")

# === Load dataset utama ===
df = pd.read_csv("../Data/cleaned_gojek_text_final.csv")

# Pastikan kolom yang dibutuhkan ada
required_cols = ['tanggal', 'stemmed_text', 'tag']
for col in required_cols:
    if col not in df.columns:
        raise KeyError(f"Kolom '{col}' tidak ditemukan di dataset!")

# 🔹 Ubah kolom tanggal ke format datetime
df['tanggal'] = pd.to_datetime(df['tanggal'], errors='coerce')


print(f"✅ Dataset berhasil dimuat: {len(df)} baris")
df.head(3)
# Out:
# ✅ Dataset berhasil dimuat: 158 baris
#                                         article_text    tanggal  \
# 0  Yogyakarta (beritajatim.com)– Pemerintah melal... 2025-02-07
# 1  Beritanusantara.co, Jakarta – Rencana pemerint... 2025-04-07
# 2  Penelitian Menyebutkan, 75% Pengguna Ojol Tola... 2025-02-03
#
#                                         cleaned_text  \
# 0  yogyakarta beritajatim com pemerintah melalui ...
# 1  beritanusantara co jakarta rencana pemerintah ...
# 2  penelitian menyebutkan pengguna ojol tolak ken...
#
#                                               tokens  \
# 0  ['yogyakarta', 'pemerintah', 'kementerian', 'p...
# 1  ['rencana', 'pemerintah', 'menaikkan', 'tarif'...
# 2  ['penelitian', 'pengguna', 'ojol', 'tolak', 'k...
#
#                                       stemmed_tokens  \
# 0  ['yogyakarta', 'perintah', 'menteri', 'hubung'...
# 1  ['rencana', 'perintah', 'naik', 'tarif', 'dasa...
# 2  ['teliti', 'guna', 'ojol', 'tolak', 'naik', 't...
#
#                                         stemmed_text  polarity sentiment  \
# 0  yogyakarta perintah menteri hubung bijak naik ...  0.000000   neutral
# 1  rencana perintah naik tarif dasar ojek online ...  0.025484   neutral
# 2  teliti guna ojol tolak naik tarif ilustrasi tu...  0.135888  positive
#
#           tag
# 0  Local News
# 1    Economic
# 2    Academic

# %% [markdown]
# Top Words TF-IDF (Time Frame)

# %%
# ============================================================
# 🧠 TF-IDF ANALYSIS PER QUARTER
# ============================================================

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer

# Pastikan kolom tanggal & teks valid
df['tanggal'] = pd.to_datetime(df['tanggal'], errors='coerce')
df = df.dropna(subset=['stemmed_text', 'tanggal']).reset_index(drop=True)

# === Tambah kolom waktu ===
df['Month'] = df['tanggal'].dt.to_period('M').astype(str)    # contoh: 2025-06
df['Quarter'] = df['tanggal'].dt.to_period('Q').astype(str)  # contoh: 2025Q2

print("🗓️ Contoh hasil transformasi waktu:")
print(df[['tanggal', 'Month', 'Quarter']].head())

# === Fungsi bantu untuk TF-IDF ===
def compute_tfidf(corpus, max_features=1000, ngram_range=(1,2)):
    """
    Hitung TF-IDF untuk kumpulan teks dan kembalikan dataframe
    dengan rata-rata skor per kata.
    """
    vectorizer = TfidfVectorizer(max_features=max_features, ngram_range=ngram_range)
    X = vectorizer.fit_transform(corpus)
    feature_names = vectorizer.get_feature_names_out()
    tfidf_df = pd.DataFrame(X.toarray(), columns=feature_names)
    tfidf_mean = tfidf_df.mean().sort_values(ascending=False)
    result = pd.DataFrame(tfidf_mean).reset_index()
    result.columns = ['term', 'tfidf']
    return result

# === TF-IDF berdasarkan Quarter ===
quarters = df['Quarter'].unique()

for q in sorted(quarters):
    subset = df[df['Quarter'] == q]
    tfidf_q = compute_tfidf(subset['stemmed_text'].astype(str))

    print(f"\n===== 🔸 Top 10 TF-IDF Words untuk {q} =====")
    print(tfidf_q.head(10))

    # === Visualisasi ===
    plt.figure(figsize=(8, 4))
    plt.barh(tfidf_q.head(10)['term'], tfidf_q.head(10)['tfidf'], color='teal')
    plt.gca().invert_yaxis()
    plt.title(f"Top 10 Words - {q}")
    plt.xlabel("TF-IDF Score")
    plt.ylabel("Word")
    plt.tight_layout()
    plt.show()
# Out:
# 🗓️ Contoh hasil transformasi waktu:
#      tanggal    Month Quarter
# 0 2025-02-07  2025-02  2025Q1
# 1 2025-04-07  2025-04  2025Q2
# 2 2025-02-03  2025-02  2025Q1
# 3 2025-02-07  2025-02  2025Q1
# 4 2025-01-07  2025-01  2025Q1
#
# ===== 🔸 Top 10 TF-IDF Words untuk 2018Q2 =====
#             term     tfidf
# 0         tampil  0.284440
# 1           guna  0.227552
# 2       aplikasi  0.227552
# 3         jemput  0.227552
# 4         driver  0.170664
# 5           ride  0.170664
# 6         lokasi  0.170664
# 7        layanan  0.170664
# 8  lokasi jemput  0.170664
# 9           baru  0.170664
# ===== 🔸 Top 10 TF-IDF Words untuk 2018Q3 =====
#               term     tfidf
# 0            tarif  0.572611
# 1            mitra  0.210962
# 2        pengemudi  0.210962
# 3           sesuai  0.180825
# 4  mitra pengemudi  0.150687
# 5            saing  0.150687
# 6            pasar  0.120550
# 7            promo  0.120550
# 8        sejahtera  0.120550
# 9     sesuai tarif  0.120550
# ===== 🔸 Top 10 TF-IDF Words untuk 2018Q4 =====
#              term     tfidf
# 0         hailing  0.198762
# 1  transportation  0.198762
# 2    ride hailing  0.198762
# 3            ride  0.198762
# 4          tariff  0.198762
# 5            said  0.198762
# 6         drivers  0.149071
# 7        business  0.149071
# 8             app  0.149071
# 9     hailing app  0.149071
# ===== 🔸 Top 10 TF-IDF Words untuk 2020Q1 =====
#         term     tfidf
# 0        pma  0.220326
# 1    ekonomi  0.176261
# 2       baca  0.176261
# 3  informasi  0.132196
# 4  investasi  0.132196
# 5  teknologi  0.132196
# 6      tirza  0.132196
# 7     lanjut  0.132196
# 8      kerja  0.132196
# 9      usaha  0.132196
# ===== 🔸 Top 10 TF-IDF Words untuk 2020Q4 =====
#               term     tfidf
# 0           bisnis  0.208389
# 1             goto  0.208389
# 2            tirza  0.173657
# 3             buka  0.173657
# 4        informasi  0.173657
# 5             baca  0.173657
# 6          persero  0.173657
# 7            usaha  0.173657
# 8            tawar  0.138926
# 9  koesoemohadiani  0.138926
# ===== 🔸 Top 10 TF-IDF Words untuk 2021Q1 =====
#                     term     tfidf
# 0               paylater  0.239474
# 1                  temen  0.239474
# 2         bayar paylater  0.179605
# 3                   cari  0.179605
# 4                  bayar  0.179605
# 5               aplikasi  0.179605
# 6                   liat  0.179605
# 7                bingung  0.119737
# 8                    bgt  0.119737
# 9  anubis plumpotatosack  0.119737
# ===== 🔸 Top 10 TF-IDF Words untuk 2021Q4 =====
#             term     tfidf
# 0          kerja  0.201048
# 1      pengemudi  0.185061
# 2           ojol  0.180292
# 3         komisi  0.151916
# 4          mitra  0.147352
# 5         potong  0.144792
# 6         persen  0.144406
# 7  potong komisi  0.110208
# 8            ade  0.094226
# 9           baca  0.086352
# ===== 🔸 Top 10 TF-IDF Words untuk 2022Q1 =====
#           term     tfidf
# 0         ojek  0.356600
# 1       online  0.356600
# 2  ojek online  0.329169
# 3       potong  0.246877
# 4        usaha  0.192015
# 5        turun  0.192015
# 6      profesi  0.164584
# 7         ojol  0.137154
# 8        kerja  0.137154
# 9     aplikasi  0.137154
# ===== 🔸 Top 10 TF-IDF Words untuk 2022Q4 =====
#          term     tfidf
# 0        naik  0.467768
# 1        ojol  0.340195
# 2       tarif  0.297670
# 3  naik tarif  0.212622
# 4      driver  0.170097
# 5      dampak  0.127573
# 6   aplikator  0.127573
# 7    kemenhub  0.127573
# 8       priyo  0.127573
# 9       biaya  0.085049
# ===== 🔸 Top 10 TF-IDF Words untuk 2023Q1 =====
#          term     tfidf
# 0       fitur  0.138920
# 1       tarif  0.122179
# 2       motor  0.111925
# 3        naik  0.111608
# 4         isu  0.103883
# 5        ojol  0.101675
# 6        nego  0.076468
# 7     indrive  0.076468
# 8  naik tarif  0.076363
# 9       emisi  0.069953
# ===== 🔸 Top 10 TF-IDF Words untuk 2023Q2 =====
#         term     tfidf
# 0  perempuan  0.243353
# 1      kerja  0.207512
# 2  pengemudi  0.200707
# 3       laki  0.121677
# 4      women  0.121677
# 5      mitra  0.120424
# 6     bentuk  0.107995
# 7      jamin  0.100353
# 8     hubung  0.090318
# 9    lindung  0.080283
# ===== 🔸 Top 10 TF-IDF Words untuk 2023Q3 =====
#                  term     tfidf
# 0               kerja  0.273557
# 1            direspon  0.179904
# 2            aspirasi  0.179904
# 3    persen responden  0.119936
# 4              persen  0.119936
# 5           responden  0.119936
# 6  responden aspirasi  0.119936
# 7   aspirasi direspon  0.119936
# 8               jalan  0.109423
# 9          jalan raya  0.109423
# ===== 🔸 Top 10 TF-IDF Words untuk 2023Q4 =====
#         term     tfidf
# 0   aplikasi  0.153233
# 1       guna  0.119845
# 2       akun  0.111356
# 3      keluh  0.088139
# 4    layanan  0.082928
# 5  pelanggan  0.074974
# 6      kurir  0.071477
# 7       baca  0.064687
# 8       pagi  0.064523
# 9     driver  0.061480
# ===== 🔸 Top 10 TF-IDF Words untuk 2024Q1 =====
#         term     tfidf
# 0     persen  0.127192
# 1      keluh  0.108016
# 2       akun  0.108016
# 3       ojol  0.103755
# 4  kombinasi  0.086735
# 5      mitra  0.081751
# 6     potong  0.066887
# 7     komisi  0.059455
# 8  pengemudi  0.059455
# 9      makan  0.058762
# ===== 🔸 Top 10 TF-IDF Words untuk 2024Q2 =====
#           term     tfidf
# 0         ojol  0.203234
# 1        hukum  0.158100
# 2        tarif  0.157385
# 3       driver  0.117641
# 4          jam  0.112344
# 5  driver ojol  0.110998
# 6       persen  0.100187
# 7         ojek  0.095398
# 8       online  0.095398
# 9  ojek online  0.091376
# ===== 🔸 Top 10 TF-IDF Words untuk 2024Q3 =====
#        term     tfidf
# 0     error  0.108349
# 1   layanan  0.074227
# 2      guna  0.072143
# 3      aman  0.067349
# 4     keluh  0.062525
# 5     mitra  0.062020
# 6     gopay  0.061547
# 7  aplikasi  0.059818
# 8     jalan  0.059714
# 9      goto  0.059661
# ===== 🔸 Top 10 TF-IDF Words untuk 2024Q4 =====
#           term     tfidf
# 0         ojek  0.196573
# 1  ojek online  0.196573
# 2       online  0.170528
# 3     koperasi  0.163396
# 4    pengemudi  0.140737
# 5        mitra  0.089509
# 6       undang  0.079434
# 7      ekonomi  0.076550
# 8       merger  0.075649
# 9         goto  0.075649
# ===== 🔸 Top 10 TF-IDF Words untuk 2025Q1 =====
#          term     tfidf
# 0       tarif  0.164928
# 1        naik  0.107572
# 2        ojol  0.094109
# 3  naik tarif  0.091481
# 4   pengemudi  0.078898
# 5      persen  0.066007
# 6       mitra  0.060612
# 7    konsumen  0.058536
# 8     triliun  0.058523
# 9       dapat  0.057945
# ===== 🔸 Top 10 TF-IDF Words untuk 2025Q2 =====
#          term     tfidf
# 0       tarif  0.166626
# 1       biaya  0.098170
# 2        naik  0.097262
# 3  naik tarif  0.078315
# 4        ojek  0.074026
# 5      persen  0.068054
# 6   pengemudi  0.067571
# 7    konsumen  0.066589
# 8      online  0.065674
# 9        ojol  0.064803
# ===== 🔸 Top 10 TF-IDF Words untuk 2025Q3 =====
#              term     tfidf
# 0        aplikasi  0.297867
# 1           biaya  0.297867
# 2        konsumen  0.248222
# 3          driver  0.223400
# 4  biaya aplikasi  0.223400
# 5           jalan  0.198578
# 6            goto  0.173756
# 7           mitra  0.173756
# 8           dapat  0.148933
# 9          potong  0.148933
# ===== 🔸 Top 10 TF-IDF Words untuk 2025Q4 =====
#            term     tfidf
# 0         mitra  0.468509
# 1        driver  0.319438
# 2  mitra driver  0.255551
# 3          naik  0.234255
# 4         tarif  0.234255
# 5   sosialisasi  0.191663
# 6    naik tarif  0.191663
# 7         bantu  0.170367
# 8       layanan  0.127775
# 9       program  0.127775

# %%
# ============================================================
# 🏷️ TF-IDF ANALYSIS BERDASARKAN CONTENT LABEL
# ============================================================

from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt

content_labels = df['tag'].dropna().unique().tolist()
print(f"🔹 Ditemukan {len(content_labels)} kategori konten:", content_labels)

for label in content_labels:
    subset = df[df['tag'] == label]
    if len(subset) < 3:
        continue  # lewati kategori dengan artikel sedikit

    tfidf_label = compute_tfidf(subset['stemmed_text'].astype(str))

    print(f"\n===== 🟦 Top 10 TF-IDF Words untuk kategori: {label.upper()} =====")
    print(tfidf_label.head(10))

    # Visualisasi
    plt.figure(figsize=(8,4))
    plt.barh(tfidf_label.head(10)['term'], tfidf_label.head(10)['tfidf'], color='darkorange')
    plt.gca().invert_yaxis()
    plt.title(f"Top 10 Words - {label.capitalize()}")
    plt.xlabel("TF-IDF Score")
    plt.ylabel("Word")
    plt.tight_layout()
    plt.show()
# Out:
# 🔹 Ditemukan 6 kategori konten: ['Local News', 'Economic', 'Academic', 'Foreign News', 'Opinion', 'Politic']
#
# ===== 🟦 Top 10 TF-IDF Words untuk kategori: LOCAL NEWS =====
#         term     tfidf
# 0   aplikasi  0.095651
# 1       guna  0.083854
# 2      mitra  0.061724
# 3      fitur  0.059722
# 4    layanan  0.057085
# 5      keluh  0.056031
# 6       akun  0.055049
# 7  pengemudi  0.052115
# 8      error  0.051604
# 9     driver  0.049420
# ===== 🟦 Top 10 TF-IDF Words untuk kategori: ECONOMIC =====
#          term     tfidf
# 0       tarif  0.147796
# 1        naik  0.104566
# 2        ojol  0.084071
# 3  naik tarif  0.083240
# 4       mitra  0.070731
# 5   pengemudi  0.070021
# 6      persen  0.062511
# 7       kerja  0.059939
# 8      driver  0.056179
# 9   aplikator  0.053225
# ===== 🟦 Top 10 TF-IDF Words untuk kategori: ACADEMIC =====
#          term     tfidf
# 0       tarif  0.176456
# 1        naik  0.109938
# 2        ojol  0.105994
# 3  naik tarif  0.087780
# 4      persen  0.086234
# 5    konsumen  0.085872
# 6        ojek  0.084978
# 7      online  0.075255
# 8       biaya  0.070598
# 9   pengemudi  0.060534
# ===== 🟦 Top 10 TF-IDF Words untuk kategori: OPINION =====
#           term     tfidf
# 0       online  0.094507
# 1         ojek  0.092513
# 2  ojek online  0.089595
# 3        tarif  0.088427
# 4    pengemudi  0.066734
# 5         ojol  0.056129
# 6    perempuan  0.053498
# 7     aplikasi  0.050962
# 8        hukum  0.049794
# 9     warganet  0.047528
# ===== 🟦 Top 10 TF-IDF Words untuk kategori: POLITIC =====
#             term     tfidf
# 0          kurir  0.126612
# 1         persen  0.124819
# 2         potong  0.123185
# 3           goto  0.122810
# 4         komisi  0.104233
# 5  potong komisi  0.094758
# 6       perintah  0.085554
# 7           ojol  0.080357
# 8      pengemudi  0.078408
# 9           atur  0.075862
