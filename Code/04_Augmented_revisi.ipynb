# %% [markdown]
# # New Section

# %%
# ==============================================================================
# === Sel 1: Markdown ===
# # Notebook: 03_Augmentasi_Data_Colab.ipynb
#
# ## Tujuan
# Notebook ini bertujuan untuk melakukan augmentasi (perbanyakan) data pada kelas sentimen
# yang jumlahnya minoritas untuk menyeimbangkan dataset. Proses ini menggunakan teknik
# back-translation, penggantian sinonim, dan parafrase sederhana.
# Mengingat proses ini intensif, notebook ini dioptimalkan untuk Google Colab.
# ==============================================================================

# === Sel 2: Kode (Instalasi Library) ===
# Instalasi library yang dibutuhkan di lingkungan Colab
# !pip install pandas deep-translator langdetect "nltk==3.8.1" Sastrawi retry openpyxl -q
print("Instalasi library selesai.")

# === Sel 3: Kode (Import & Hubungkan Google Drive) ===
import pandas as pd
import re
import logging
from deep_translator import GoogleTranslator
from langdetect import detect, LangDetectException
import random
import time
from retry import retry
from nltk.tokenize import word_tokenize
import nltk
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from multiprocessing import Pool, cpu_count
import numpy as np
import os
from google.colab import drive

# Hubungkan ke Google Drive
drive.mount('/content/drive')
print("Google Drive berhasil terhubung.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 13.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 28.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 3.7 MB/s eta 0:00:00
#   Building wheel for langdetect (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# textblob 0.19.0 requires nltk>=3.9, but you have nltk 3.8.1 which is incompatible.
# Instalasi library selesai.
# Mounted at /content/drive
# Google Drive berhasil terhubung.

# %%
# === Sel 4: Kode (Definisi Path dan Inisialisasi) ===
# Inisialisasi logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# --- MOHON SESUAIKAN PATH INI ---
# Ganti 'Proyek_Sentimen_Gojek' dengan nama folder proyek Anda di Google Drive
drive_path = '/content/drive/MyDrive/Proyek_Sentimen_Gojek/'
# --------------------------------

# Definisikan path untuk folder data
data_folder = os.path.join(drive_path, 'Data')

# Buat folder jika belum ada
os.makedirs(data_folder, exist_ok=True)
logger.info(f"Folder 'Data' siap digunakan di: {data_folder}")


# Unduh paket NLTK jika belum ada
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt')
    nltk.download('punkt_tab')
print("Paket NLTK sudah siap.")
# Out:
# Paket NLTK sudah siap.

# %%
# === Sel 5: Kode (Definisi Fungsi Utilitas dan Augmentasi) ===

# Tambahkan import sent_tokenize
from nltk.tokenize import sent_tokenize

# --- FUNGSI BARU UNTUK CHUNKING ---
def chunk_text(text, max_length=4500):
    """Membagi teks panjang menjadi beberapa bagian (chunks) berdasarkan kalimat."""
    # Download 'punkt' jika belum ada untuk tokenisasi kalimat
    try:
        nltk.data.find('tokenizers/punkt')
    except LookupError:
        nltk.download('punkt')

    sentences = sent_tokenize(text)
    chunks = []
    current_chunk = ""
    for sentence in sentences:
        if len(current_chunk) + len(sentence) + 1 <= max_length:
            current_chunk += sentence + " "
        else:
            chunks.append(current_chunk.strip())
            current_chunk = sentence + " "
    if current_chunk:
        chunks.append(current_chunk.strip())
    return chunks

translation_cache = {}

@retry(tries=3, delay=2, backoff=2)
def back_translate(text, intermediate_lang='en'):
    """Fungsi untuk back-translation dengan caching dan retry."""
    # Fungsi truncate_text dihapus karena prosesnya kini ditangani oleh chunking
    try:
        if text in translation_cache:
            return translation_cache[text]

        translated = GoogleTranslator(source='id', target=intermediate_lang).translate(text)
        time.sleep(0.5) # Jeda untuk menghindari rate limit
        back_translated = GoogleTranslator(source=intermediate_lang, target='id').translate(translated)
        time.sleep(0.5)

        if back_translated:
            translation_cache[text] = back_translated
            return back_translated
        return text # Kembalikan teks asli jika gagal
    except Exception as e:
        logger.error(f"Error pada back-translation: {e}")
        return text

# Kamus sinonim untuk penggantian kata
synonym_dict = {
    'pembangunan': ['konstruksi', 'pengembangan', 'pendirian'],
    'proyek': ['rencana', 'pekerjaan', 'program'],
    'investasi': ['penanaman modal', 'pendanaan', 'modal'],
    'infrastruktur': ['sarana', 'prasarana', 'fasilitas'],
    'layanan': ['jasa', 'servis'],
    'driver': ['pengemudi', 'mitra'],
    'tarif': ['ongkos', 'biaya'],
    'aplikasi': ['platform', 'sistem']
}

gojek_keywords = [
    'gojek', 'goto', 'ojol', 'driver', 'aplikasi', 'layanan', 'tarif',
    'gofood', 'gopay', 'transportasi', 'ojek', 'online'
]

stemmer = StemmerFactory().create_stemmer()

def synonym_replacement(text, n=3):
    """Mengganti n kata secara acak dengan sinonimnya."""
    try:
        words = word_tokenize(text)
        new_words = words.copy()
        indices = [i for i, word in enumerate(words) if word.lower() in synonym_dict]
        random.shuffle(indices)

        replaced_count = 0
        for i in indices:
            if replaced_count < n:
                synonym = random.choice(synonym_dict[words[i].lower()])
                if synonym.lower() != words[i].lower():
                    new_words[i] = synonym
                    replaced_count += 1
            else:
                break
        return " ".join(new_words)
    except Exception as e:
        logger.error(f"Error in synonym_replacement: {e}")
        return text

# --- FUNGSI WRAPPER BARU UNTUK AUGMENTASI DENGAN CHUNKING ---
def augment_text_in_chunks(text, augment_func, **kwargs):
    """
    Melakukan augmentasi pada teks dengan membaginya menjadi chunks terlebih dahulu.
    """
    if len(text) < 4500: # Jika teks tidak terlalu panjang, langsung proses
        return augment_func(text, **kwargs)

    # Jika teks panjang, bagi menjadi chunks
    chunks = chunk_text(text)
    augmented_chunks = [augment_func(chunk, **kwargs) for chunk in chunks]
    return " ".join(augmented_chunks)

def validate_augmented_text(text):
    """Memvalidasi apakah teks hasil augmentasi masih relevan."""
    try:
        if len(text.split()) < 5: return False
        try:
            is_id = detect(text) == 'id'
        except LangDetectException:
            is_id = False
        if not is_id: return False

        keyword_count = sum(1 for keyword in gojek_keywords if keyword.lower() in text.lower())
        return keyword_count >= 2
    except Exception as e:
        logger.error(f"Error in validate_augmented_text: {e}")
        return False

def augment_row(row_tuple):
    """Fungsi wrapper untuk augmentasi satu baris data (untuk multiprocessing)."""
    index, row, intermediate_langs = row_tuple
    try:
        original_text = row['cleaned_content']
        method = random.choice(['back_translate', 'synonym'])

        if method == 'back_translate':
            lang = random.choice(intermediate_langs)
            # Gunakan fungsi wrapper chunking untuk back-translation
            augmented_text = augment_text_in_chunks(original_text, back_translate, intermediate_lang=lang)
        else:
            # Gunakan fungsi wrapper chunking untuk penggantian sinonim
            augmented_text = augment_text_in_chunks(original_text, synonym_replacement, n=3)

        if augmented_text and augmented_text != original_text and validate_augmented_text(augmented_text):
            new_row = row.copy()
            new_row['cleaned_content'] = augmented_text
            new_row['is_augmented'] = True
            return new_row
        return None
    except Exception as e:
        logger.error(f"Error dalam augment_row di baris {index}: {e}")
        return None

# %%
# === Sel 6: Kode (Pipeline Augmentasi Utama) ===

# Path file input (hasil dari notebook 02)
input_file = os.path.join(data_folder, 'gojek_news_preprocessed.csv')
try:
    df = pd.read_csv(input_file)
    logger.info(f"Berhasil memuat file '{input_file}' dengan {len(df)} baris.")
except FileNotFoundError:
    logger.error(f"File '{input_file}' tidak ditemukan. Jalankan notebook preprocessing terlebih dahulu.")
    raise SystemExit(1)


if __name__ == '__main__' and not df.empty:
    # Tambahkan kolom 'label' jika tidak ada (untuk pengujian)
    if 'label' not in df.columns:
        logger.warning("Kolom 'label' tidak ditemukan. Menggunakan 'tag' sebagai 'label'.")
        df['label'] = df['tag'] # Asumsikan 'tag' adalah kolom sentimen

    TARGET_PER_LABEL = 150
    INTERMEDIATE_LANGS = ['en', 'fr', 'de', 'es']

    final_dfs = []
    logger.info(f"Memulai proses augmentasi untuk mencapai target {TARGET_PER_LABEL} data per label...")

    for label in df['label'].unique():
        subset = df[df['label'] == label].copy()
        count = len(subset)
        logger.info(f"Label '{label}' memiliki {count} data.")

        if count >= TARGET_PER_LABEL:
            sampled = subset.sample(n=TARGET_PER_LABEL, random_state=42).copy()
            sampled['is_augmented'] = False
            final_dfs.append(sampled)
        else:
            subset['is_augmented'] = False
            final_dfs.append(subset)
            n_to_augment = TARGET_PER_LABEL - count
            logger.info(f"Label '{label}': Perlu augmentasi sebanyak {n_to_augment} data.")

            # Oversample untuk antisipasi kegagalan validasi
            rows_to_augment_indices = [i % count for i in range(n_to_augment * 2)]
            rows_to_augment = [(index, subset.iloc[index].copy(), INTERMEDIATE_LANGS) for index in rows_to_augment_indices]

            # Menggunakan multiprocessing untuk mempercepat proses
            with Pool(processes=max(1, cpu_count() - 1)) as pool:
                results = pool.map(augment_row, rows_to_augment)

            augmented_rows = [row for row in results if row is not None][:n_to_augment]

            if len(augmented_rows) < n_to_augment:
                logger.warning(f"Label '{label}': Hanya {len(augmented_rows)} data berhasil diaugmentasi. Sisanya diisi dengan duplikasi.")
                remaining = n_to_augment - len(augmented_rows)
                fallback_rows = [subset.iloc[i % count].copy() for i in range(remaining)]
                for row in fallback_rows:
                    row['is_augmented'] = False # Tandai sebagai tidak di-augmentasi
                augmented_rows.extend(fallback_rows)

            df_aug = pd.DataFrame(augmented_rows)
            final_dfs.append(df_aug)

    df_final = pd.concat(final_dfs, ignore_index=True)

    # Simpan hasil augmentasi
    output_path_csv = os.path.join(data_folder, 'gojek_news_augmented.csv')
    output_path_xlsx = os.path.join(data_folder, 'gojek_news_augmented.xlsx')
    df_final.to_csv(output_path_csv, index=False)
    df_final.to_excel(output_path_xlsx, index=False)

    logger.info("--- PROSES AUGMENTASI SELESAI ---")
    logger.info(f"Data augmented disimpan di '{output_path_csv}' dan '{output_path_xlsx}'")
    logger.info(f"Total data akhir: {len(df_final)}")
    logger.info(f"Distribusi label baru:\n{df_final['label'].value_counts().to_string()}")

    print("\nSampel data hasil augmentasi:")
    from IPython.display import display
    display(df_final.sample(10)[['cleaned_content', 'label', 'is_augmented']])
# Out:
# WARNING:__main__:Kolom 'label' tidak ditemukan. Menggunakan 'tag' sebagai 'label'.
# ERROR:__main__:Error pada back-translation: Des milliers de chauffeurs de moto-taxi en ligne membres de l’Association des gardes indonésiens organiseront une action majeure en mai 2025 à Jakarta. Cette action s'est caractérisée par une offre massive, à savoir la suppression simultanée des services d'application dans toute l'Indonésie, en guise de protestation contre une baisse des revenus jugée injuste. Les conducteurs exigent une limite maximale de déduction de pour cent, alors qu'ils affirment qu'actuellement les déductions des applicateurs peuvent atteindre près de pour cent, un lourd fardeau dans un contexte de faibles revenus quotidiens. Cette condition est considérée comme étant en conflit avec les réglementations gouvernementales, telles que le Permenhub PM n° 122019 et le décret du ministère des Transports n° 10012022, 1905. Cette vague d'insatisfaction a en fait émergé depuis le dernier Eid al-Fitr, lorsque les conducteurs ont également exigé des indemnités de vacances. Le président Prabowo avait fait appel à la plateforme pour qu'elle accorde une prime de vacances BHR de 1 million IDR par conducteur, qui a ensuite été officialisée par une lettre circulaire du ministre de la Main-d'œuvre. Cependant, la réalisation a été loin des attentes, de nombreux conducteurs n’ont reçu que 1 000 000 Rp. et ce n'est pas réparti uniformément. La racine du problème réside dans le statut de partenariat qui a été le bouclier juridique de l'entreprise plateforme. Ce statut n'est pas réglementé par la loi numéro 2003 concernant l'emploi et la création d'emplois. Cela revient à libérer l’entreprise de ses obligations d’employeur, même si elle bénéficie toujours du travail des chauffeurs partenaires. Depuis l’émergence des services de covoiturage comme Uber en 2014 et __Gojek__ en 2015, les relations de travail dans l’économie numérique sont laissées dans une zone grise juridique, sans certitude de protection des travailleurs. Ce phénomène reflète le retard de la réglementation indonésienne du travail à répondre à la dynamique de l’industrie numérique de plus en plus dominante. Sans réforme juridique adéquate, des millions de travailleurs à la demande continueront de vivre dans des conditions de travail injustes, contribuant ainsi à l’économie nationale, mais sans garantir les droits fondamentaux des travailleurs. L’Indonésie n’est pas le seul pays confronté à des problèmes de relations de travail à l’ère de la « gig economy ». Cependant, par rapport aux pays voisins comme Singapour, la Malaisie et le Vietnam, la protection des travailleurs des plateformes en Indonésie, en particulier les chauffeurs de moto-taxi en ligne, est encore à la traîne, tant sur le plan juridique que dans les politiques de protection sociale. À Singapour, la réglementation concernant les chauffeurs de taxi en ligne est très structurée. Le gouvernement exige que les conducteurs soient titulaires d'un permis professionnel VL, qui ne s'obtient qu'après avoir suivi une formation en matière de sécurité et réussi un examen de santé. De plus, l'autorité des transports de Singapour LTA a mis en place un système de quotas pour limiter le nombre de véhicules de covoiturage, afin d'éviter la saturation du marché. L'assurance contre les accidents du travail est également une nécessité et Grab a collaboré avec Futuready Insurance pour fournir cette protection. Cependant, la pression du coût de la vie élevé reste un fardeau énorme pour les conducteurs, car la protection du revenu
développement de l’économie numérique. Le DPR et le gouvernement doivent immédiatement rédiger une loi spéciale qui réglemente les relations de travail dans l’économie numérique, y compris la protection sociale, la transparence des algorithmes et des normes de revenu équitables pour les travailleurs à la demande. Deuxièmement, exiger une protection sociale pour les travailleurs à la demande. Actuellement, seul un petit nombre de chauffeurs de taxi-moto sont enregistrés auprès de BPJS Employment et BPJS Health. troisièmement, établir un dialogue entre les p ...
# ERROR:__main__:Error pada back-translation: Le gouvernement, par l’intermédiaire du ministère des Transports, prévoit d’augmenter les tarifs des motos-taxis en ligne d’ici 2025. Même si cette politique vise à améliorer le bien-être des conducteurs, la réaction du public témoigne de l’inquiétude, en particulier de la part des consommateurs sensibles aux prix. Sur la base des résultats des recherches et de la littérature internationale, ce discours doit être étudié plus profondément quantitativement et structurellement. Les consommateurs sont très sensibles aux changements de tarifs. Des études menées en 2019 et 2022 montrent systématiquement que la majorité des utilisateurs de taxis moto en ligne sont issus de la classe moyenne inférieure et font du prix le principal facteur dans les décisions d'utilisation. En 2019, les personnes interrogées ont déclaré qu'elles utilisaient les motos-taxis en ligne parce qu'elles permettaient d'économiser sur les coûts de transport. dans la simulation tarifaire, seuls les consommateurs sont prêts à accepter l'augmentation après prise en compte de la commission d'application de . En 2022, les personnes interrogées ont déclaré qu'elles n'étaient pas d'accord avec l'augmentation des tarifs et ont déclaré qu'elles recommenceraient à utiliser des véhicules privés si les tarifs continuaient d'augmenter. Ce résultat est cohérent avec les études internationales, qui montrent que le secteur du covoiturage est un service à prix élastique. autrement dit, les augmentations de prix ont tendance à réduire considérablement le nombre d'utilisateurs, en particulier dans le segment des utilisateurs quotidiens qui est sensible aux coûts. Pourtant, les résultats de plusieurs études montrent que la réalité n’est pas si simple. Si une augmentation des tarifs entraîne une diminution de la demande, le nombre de commandes diminuera et les revenus totaux pourront stagner, voire diminuer. La structure de commission mise en place par les sociétés d'applications signifie généralement que l'augmentation des tarifs n'augmente pas nécessairement directement la part du conducteur. Les rapports publics des sociétés de covoiturage montrent que la plupart des marges sont allouées aux coûts d'exploitation et aux promotions, et non aux incitations aux conducteurs. Les études de l’OIT et de l’Indef montrent également que l’incertitude des revenus, le manque de transparence dans le calcul des revenus et le fardeau des coûts opérationnels constituent les principaux défis pour le bien-être des chauffeurs de moto-taxi en ligne. Des augmentations de tarifs sans modification de la structure des incitations ne feront que perpétuer le problème. les applications ont besoin de transparence dans la répartition de la valeur. Les sociétés d'applications affirment que la baisse des commissions ou le plafonnement des taux risquent de réduire les performances des services en réduisant l'espace réservé à l'innovation et aux opérations. cependant, les rapports d'introduction en bourse __goto__ et grab montrent que la plupart des revenus de la plate-forme proviennent des commissions de service, et non de la rentabilité. cela soulève des questions sur la répartition équitable de la valeur économique entre les entreprises, les conducteurs et les consommateurs. Une communication transparente et bidirectionnelle entre les prestataires de services et les chauffeurs partenaires est très importante dans toute nouvelle mise en œuvre de politique. recherche menée en 2019 impliquant . Les personnes interrogées ont indiqué qu'une approche de communication ouverte, telle que des réunions en face-à-face lors de la transmission de politiques importantes, notamment la politique de suspension, s'est avérée plus efficace pour renforcer la confiance et les perceptions de transparence entre les conducteurs. Cette approche peut également être appliquée en réponse aux politiques d’augmentation minimale des tarifs, afin de garantir une compréhension mutuelle et de réduire ...
# ERROR:__main__:Error pada back-translation: Jakarta, Kompas PT __goto__ __gojek__ Tokopedia Tbk assure que les services __Gojek__ restent normaux même si certains de ses partenaires ont décidé de désactiver l'application pendant la manifestation. L'entreprise respectera ses partenaires qui souhaitent transmettre leurs aspirations, mais n'arrêtera pas nécessairement les services. Le chef des relations gouvernementales en matière de politique publique __goto__ Ade Mulya, dans sa déclaration du lundi 1952025, a déclaré que son parti respecte le droit de chaque individu d'exprimer ses opinions, y compris les partenaires conducteurs qui choisissent d'exprimer leurs aspirations. Ade veille à ce que __gojek__ soit toujours ouvert aux aspirations des partenaires conducteurs actifs et les exhorte à les transmettre de manière ordonnée et propice. Jusqu'à présent, divers canaux de communication formels ont été disponibles pour permettre les commentaires et les discussions constructives des partenaires. Dans le même temps, __gojek__ soutient pleinement les chauffeurs partenaires qui choisissent toujours de fonctionner et de terminer les commandes comme d'habitude. "Nous nous engageons à maintenir un écosystème sûr, confortable et productif pour toutes les parties, chauffeurs partenaires et clients", a déclaré Ade. Concernant les éventuelles interruptions de service dues aux manifestations de mai 2025, Ade a déclaré que les opérations de __gojek__ continueraient de se dérouler normalement et que les clients pourraient toujours utiliser le service comme d'habitude. Concernant la demande de réduire la commission à un pourcentage, Ade estime que ce n'est pas une solution. Selon lui, les commissions ou frais de service prélevés sur les tarifs ou les frais de déplacement à hauteur d'un pourcentage sont utilisés pour financer divers efforts visant à assurer la pérennité des niveaux de commandes et des opportunités de revenus des partenaires. Grâce à cette commission, l'entreprise est en mesure de proposer des promotions et des remises pour attirer les clients afin que le volume des commandes soit maintenu afin de pouvoir continuer à maintenir la pérennité du revenu total des chauffeurs partenaires. La commission constitue également une incitation et une aide personnelle pour les chauffeurs partenaires, sous la forme d'un revenu supplémentaire et d'une aide aux opérations partenaires. La commission sert également à financer l’assurance voyage des chauffeurs partenaires et des clients. En dehors de cela, les commissions sont utilisées pour financer d’autres coûts, tels que les taxes, les frais de marketing, etc. Ade assure que __Gojek__ s'engage à se conformer aux réglementations fixées par le gouvernement, en l'occurrence le ministère des Transports, ministère des Transports. Les frais de service ou commissions __gojek__ pour les services de passagers à deux roues font toujours référence à la décision du ministre des Transports KP numéro 1001 en date de novembre 2022, où il existe deux types de composants constitués de coûts indirects sous la forme de frais de location pour l'utilisation de l'application au pourcentage le plus élevé et de frais de support pour cent. "Chaque trimestre, nous faisons rapport au ministère des Transports pour nous assurer que cette commission est utilisée pour soutenir la durabilité des commandes et les revenus des partenaires", a-t-il déclaré. Selon Ade, environ pour cent de la valeur brute totale des transactions est reversé à l'écosystème des partenaires, y compris les paiements directs aux chauffeurs partenaires, aux commerçants partenaires, aux clients, ainsi que les investissements dans les programmes d'incitation, les opérations et le développement technologique visant à augmenter les opportunités de revenus des partenaires. L'entreprise comprend que le bien-être doit être considéré de manière globale. Il doit y avoir un équilibre optimal entre les partenaires obtenant un revenu décent, les clients toujours ser ...
ertinentes pour le développement de l’économie numérique. Le DPR et le gouvernement doivent immédiatement rédiger une loi spéciale qui réglemente les relations de travail dans l’économie numérique, y compris la protection sociale, la transparence des algorithmes et des normes de revenu équitables pour les travailleurs à la demande. Deuxièmement, exiger une protection sociale pour les travailleurs à la demande. Actuellement, seul un petit nombre de chauffeurs de taxi-moto sont enregistrés auprès de BPJS Employment et BPJS Health. troisièmement, établir un dialogue entre les p ...
# ERROR:__main__:Error pada back-translation: Die Befragung der Mehrheit der Nutzer, die trotz steigender Fahrpreise weiterhin Motorradtaxis nutzen, zeigt, wie abhängig städtische Gemeinden in Jakarta vom Online-Transport mit Motorradtaxis sind. Die Umfrageergebnisse des Meinungsforschungsinstituts ergaben, dass bis zu 10 Prozent der Online-Nutzer von Ojol-Motorradtaxis weiterhin Ojols nutzen werden, auch wenn die Fahrpreise aufgrund der gestiegenen Kraftstoffpreise steigen. Der Geschäftsführer des Kennedy Muslim Polling Institute erklärte in seiner Online-Präsentation am Sonntag in Jakarta, dass die Entscheidung, weiterhin wie gewohnt Motorradtaxis zu nutzen, die wichtigste Option sei, gefolgt von der Option, ein privates Motorrad zu nutzen. Die Möglichkeit, Ojol weiterhin wie gewohnt zu nutzen, ist in der Tat der höchste Prozentsatz, den es gibt. „Das zeigt, wie abhängig städtische Gemeinden vom Online-Transport mit Motorradtaxis sind“, sagte er. Die zweithöchste Reaktion, wenn die Erhöhung der Motorradtaxi-Tarife umgesetzt wird, sei, so Kennedy weiter, die Nutzung eines privaten Motorrads um 10 %, gefolgt von der weiteren Nutzung eines Motorrads und einer Kombination aus dem eigenen Motorrad um 100 %, der Nutzung des eigenen Motorrads für öffentliche Verkehrsmittel (100 %) oder der Nutzung öffentlicher Verkehrsmittel (10 %). „Tatsächlich sehen wir, dass die Zahl derer, die auf öffentliche Verkehrsmittel umsteigen, mit durchschnittlich unter sechs Prozent immer noch sehr gering ist“, sagte er. Darüber hinaus erklärte Kennedy, dass die Erhöhung der Motorradtaxi-Tarife auch eine Bedrohung für die Motorradtaxi-Partner selbst darstelle. Bei einer Tariferhöhung von beispielsweise 2 IDR pro Fahrt kehren etwa Prozent der Nutzer zurück und wechseln in einen anderen Modus. Wenn die Tariferhöhung hingegen etwa 4 IDR pro Fahrt erreicht, ist es wahrscheinlich, dass etwa ein Prozent der Nutzer Ojol nicht mehr nutzen werden. Obwohl die Mehrheit der Fahrerpartner der Fahrpreiserhöhung voll und ganz zustimmt, werden die logischen Konsequenzen, die sich aus der Fahrpreiserhöhung ergeben, von den Fahrerpartnern daher sehr widersprüchlich beurteilt. Die Mehrheit tendiert dazu, sich auf Auftragsvolumina zu konzentrieren, die nicht sinken, ohne dass die Raten steigen, , Prozent. oder sogar eine ganze Reihe von Partnern, die eine Senkung der Zölle wünschen, damit sie mehr bestellen können, sagte er. Kennedy sagte, dass der Anstieg der Kraftstoffpreise aufgrund der Erhöhung der Motorradtaxi-Tarife wahrscheinlich einen dämpfen
culinaires à domicile aux petits magasins, faisant des chauffeurs de taxi-moto non seulement des fournisseurs de transport, mais aussi des rouages ​​vitaux pour l'économie __umkm__. En dehors de cela, cette industrie crée des millions d'emplois, absorbe des travailleurs informels et contribue de manière significative au PIB national, à partir de __umkm__, et réduit le chômage, démontrant ainsi son rôle important dans l'amélioration du bien-être de la population. faites défiler pour continuer avec le contenu Cependant, malgré cette grande contribution, le bien-être des chauffeurs de taxi-moto en ligne reste une question cruciale. un système de répartition des bénéfices injuste et tendant à favoriser le demandeur, ainsi qu'un statut de partenaire qui élimine la protection du travail décent, sont les principales plaintes. Les conducteurs doivent supporter leurs propres coûts opérationnels, le risque d’accident et un soutien minimal de la part de l’entreprise. des incitations qui continuent de diminuer, des taux de candidature qui ne sont pas équilibrés et une aide minimale, par exemple seulement 1 000 000 Rp). 50. pendant l'Aïd al-Fitr aggrave leur situation financière. La racine du problème réside dans la pratique consistant à réduire les tarifs qui dépassent les limites raisonnables, atteignant même 5 070 % du tarif du client, bien au-dessus de la limite maximale réglementée par le gouvernement. par exemple, le conducteur ne peut recevoir que 1 000 000 Rp. 5. à partir de Rp. 18. Cette pratique témoigne d'une exploitation préjudiciable aux conducteurs, qui doivent travailler de plus longues heures avec des revenus en baisse, tandis que les coûts d'exploitation continuent d'augmenter. publicité Le manque de transparence dans la détermination des tarifs constitue également un reproche sérieux. le conducteur ne se sent pas impliqué dans la prise de décision, l'applicateur a donc toute autorité. Cette incertitude et ce manque de contrôle sur les tarifs créent un sentiment d'insécurité et d'injustice qui a un impact sur la qualité de vie et la motivation au travail des conducteurs, ce qui suscite des de ...
# ...
# ERROR:__main__:Error pada back-translation: Im Folgenden sind die Paint-Point-Ergebnisse aufgeführt, die wir in der Emphatize-Sitzung erhalten haben, einschließlich der Eingabetaste oder des Klicks, um das Bild in voller Größe anzuzeigen. „How Might We“ Der nächste Schritt besteht darin, „How Might We“ zu bestimmen und einen Abstimmungsprozess darüber durchzuführen, welches HMW vom Team am meisten ausgewählt und umgesetzt wird. Im Folgenden finden Sie die Abstimmungsergebnisse, die wir durch Drücken der Eingabetaste oder Klicken ausgewählt haben, um das Bild in voller Größe anzuzeigen. Idee. Ideate ist eine Phase im Design, in der durch den Fokus des Denkens Ideen zur Lösung eines definierten Problems entstehen. Es nutzt Kreativität, um verschiedene Konzepte zu entwickeln und die besten Lösungen für die Umsetzung auszuwählen. Diese Phase besteht nur aus der Lösungsphase, Ideen und Aktivitäten zur Verwirklichung unseres Könnens. Affinitätsdiagramm zur Gruppierung von Lösungsideen und deren Zuordnung zu Funktionen, die in der Anwendung entwickelt werden können. Hier liegt der Fokus auf kreativem Denken, um eine Vielzahl unterschiedlicher Konzepte zu entwickeln. Diese Ideen werden dann nach Typ gruppiert und der Reihe nach nach Priorität umgesetzt. Lösungsidee: Drücken Sie die Eingabetaste oder klicken Sie, um das Bild im Affinitätsdiagramm in voller Größe anzuzeigen. Drücken Sie die Eingabetaste oder klicken Sie, um das Bild in voller Größe anzuzeigen. Prototyp. Prototypen können physische Modelle, Zeichnungen, Simulationen und digitale Prototypen sein. Ihr Hauptziel besteht darin, bessere Entscheidungen zu treffen und Benutzern die Möglichkeit zu geben, ihre Ideen zu testen, zu bewerten und zu verfeinern. Dieser Prozess besteht aus einem Benutzerfluss-Wireframe-UI-Modell und einem Prototyp. Benutzerfluss Dieser Benutzerfluss ist der Prozess des Zugriffs auf Dienste, um Benutzeranforderungen zu erfüllen, mit einer Beschreibung der Schritte, die befolgt werden müssen, und der verwendeten Denkprozesse. Hier ist der Benutzerfluss, den wir entworfen haben. Drücken Sie die Eingabetaste oder klicken Sie, um das Bild in voller Größe anzuzeigen. Benutzerfluss-Anmeldung. Drücken Sie die Eingabetaste oder klicken Sie, um das Bild in voller Größe anzuzeigen. Benutzerflussauftrag. Drücken Sie die Eingabetaste oder klicken Sie, um das Bild in voller Größe anzuzeigen. Benutzerflusstreiber-Drahtmodell. Diese Phase ist die Grundstruktur der Anwendungsseite, die das grundlegende Design ihrer Teile wie Inhalt, Layout, Navigation und andere enthält. Dies ist nützlich, um zu verstehen, wie die Anwendung aussieht, bevor sie tatsächlich entwickelt wird. Drücken Sie die Eingabetaste oder klicken Sie, um das Bild im Drahtmodell in voller Größe anzuzeigen. Anmelden, registrieren, OTP. Drücken Sie die Eingabetaste oder klicken Sie, um das Bild im Drahtmodell in voller Größe anzuzeigen. Beifahrerbildschirm. Wählen Sie die Zahlungsmethode. Drücken Sie die Eingabetaste oder klicken Sie, um das Bild im Drahtmodell in voller Größe anzuzeigen. Fahrerbildschirm. Benachrichtigungsalarm-Designsystem. Man kann sagen, dass das in diesem Fall geschaffene System alles andere als perfekt ist. Erstellen eines Designsystems unter Verwendung des Konzepts des Atomdesigns. Das Systemdesign erfolgt aus den kleinsten Komponenten, nämlich Atomen, wie Farbe und Typografie. Drücken Sie die Eingabetaste oder klicken Sie, um das Bild in voller Größe anzuzeigen. Drücken Sie die Eingabetaste oder klicken Sie, um das Bild in voller Größe anzuzeigen. Stileingabe, Dropdown, Typografie und Farbe. Drücken Sie die Eingabetaste oder klicken Sie, um das Bild in voller Größe anzuzeigen. Die Stile für Kontrollkästchen, Statusleiste, Optionsfeld, Umschalter und Radiosymbole sind in der folgenden Figma-Datei zu sehen. UI-Modell und Prototyp. In dieser Phase treten wir in die Umsetzungsphase der genannten Ideen ein. Entwerfen Sie dann in der Hoffnung, die Form des Endprodukts zu ändern, um den  ...
# ERROR:__main__:Error pada back-translation: Toutefois, ces deux règles juridiques ont des substances différentes. Les partenariats civils régis par le Code pénal sont idéalement des entités commerciales gérées par les parties dans des conditions relativement égales. il y a place au dialogue pour formuler les règles de conduite qui seront mises en œuvre. Pendant ce temps, dans l’accord de partenariat entre l’application et le conducteur, il n’y a absolument aucune marge de négociation. tout est déterminé par des clauses types fixées par l'application qui est d'ailleurs une entreprise. ce qui signifie que dès le départ, le conducteur a été positionné comme subordonné à l’application. De plus, dans l'exercice de leurs activités, les conducteurs restent soumis aux dispositions de l'application qui s'apparentent en réalité davantage à la réglementation de l'entreprise. l'espace de négociation est à nouveau presque fermé, à l'exception peut-être de manifestations à grande échelle des conducteurs. À ce stade, la tendance semble de plus en plus être une relation entre le travailleur et l’employeur et, encore une fois, non entre partenaires. S'appuyant sur les dispositions du Code pénal, UU __umkm__, tel que partiellement modifié par la loi sur la création d'emplois, réglemente également les partenariats. Dans l'article numéro UU __umkm__, il est indiqué que le partenariat est une coopération dans les relations commerciales, à la fois directes et indirectes, basée sur les principes de besoin mutuel, de confiance, de renforcement et de bénéfice impliquant des acteurs de micro, petites et moyennes entreprises avec de grandes entreprises. Sur la base de cette disposition, il existe au moins trois aspects permettant d'apprécier la légalité du partenariat entre la demande et le conducteur, à savoir l'aspect matériel de l'accord de partenariat, l'aspect critères des parties au partenariat et l'aspect mise en œuvre du partenariat. En ce qui concerne la conclusion d'un accord de partenariat, basé sur la définition donnée par UU __umkm__, idéalement, l'accord répond aux principes de besoin mutuel, de confiance, de renforcement et d'avantage. Cependant, en plus d'être conclu sans processus de dialogue comme preuve que les parties sont sur un pied d'égalité, le contenu de l'accord de partenariat conclu selon un format de clause standard semble très boiteux. dans l'accord de partenariat __gojek__, par exemple, plusieurs parties imposent une lourde charge au conducteur. d'après les phrases utilisées seules, il apparaît que le conducteur est subordonné à l'application, c'est-à-dire votre responsabilité en tant que partenaire, votre engagement en tant que partenaire, etc. par contre, dans cet accord il y a tellement de phrases que gojekkami n'est pas responsable. Il apparaît donc que les aspects substantiels de l’accord de partenariat ne sont pas respectés. Ensuite, en ce qui concerne les critères de sélection des parties à un partenariat, il apparaît que les parties pouvant s'associer sont les micro, petites et moyennes entreprises et les grandes entreprises. Si l'application peut être clairement classée comme une grande entreprise, alors où est la position du conducteur, qu'elle soit classée comme une micro, petite ou moyenne entreprise, les exigences pour devenir une micro, petite et moyenne entreprise ont été initialement réglementées dans UU __umkm__. Cependant, après la ratification de la loi omnibus sur le droit d'auteur des œuvres, les critères applicables aux micro-entreprises sont réglementés dans le règlement gouvernemental numéro 2021 concernant la commodité, la protection et l'autonomisation des coopératives et des petites, micro et moyennes entreprises PP 72021. En référence aux dispositions de l'article PP, les micro, petites et moyennes entreprises sont déterminées sur la base des critères du capital commercial ou des résultats de ventes annuels. Cependant, cette division n'est pas très importante, car, pour être désignées comme micro ...
# ERROR:__main__:Error pada back-translation: Yakarta, Kompas, la empresa de tecnología de aplicaciones de Indonesia, __gojek__, ha evolucionado hasta convertirse en una superaplicación o superaplicación para un ecosistema integrado que mueve personas, bienes y dinero. no sólo para los usuarios, __gojek__ también proporciona aplicaciones para ayudar a los socios y comerciantes que colaboran. El director ejecutivo del grupo __gojek__, nadiem makarim, dijo que nunca esperó que __gojek__ se convirtiera en lo que es ahora. __gojek__ se ha convertido en un movimiento en sí mismo, no solo una empresa, sino una revolución que se está produciendo en los campos de la tecnología y la humanidad, dijo en la oficina de __gojek__, el lunes 227 de 2019. Nadem dijo que la empresa que fundó en 2010 inicialmente sólo se dedicaba al negocio de transporte de vehículos de dos ruedas o mototaxi basado en centros de llamadas y páginas web. cinco años más tarde, __gojek__ creó una aplicación para teléfonos inteligentes y lanzó tres servicios distintos de los mototaxis o llamados goride, a saber, el servicio de pedidos de alimentos __gofood__, la entrega de mercancías gosend y las compras gomart. En 2016, __gojek__ lanzó la billetera digital __gopay__ y el servicio de taxi en línea gocar. Desde entonces, esta nueva empresa ha recibido el título de unicornio porque tiene una valoración o un valor de ventas de hasta mil millones de dólares estadounidenses o más de 14 billones de IDR. Este año, __gojek__ se convirtió en la principal startup del mundo con estatus decacornio porque tiene una valoración de más de 10 mil millones de dólares estadounidenses o el equivalente a 140 billones de IDR. Según la encuesta cbinsights, __gojek__ ocupa el puesto 18. Mientras tanto, una empresa similar con sede en el sudeste asiático, Grab, ocupa la novena posición entre las startups con estatus de unicornio en el mundo. El número de transacciones __gojek__ ha crecido rápidamente en los últimos tres años. De junio de 2016 a junio de 2019, el número de transacciones procesadas en la plataforma de servicios se disparó a . por ciento o veces. __gojek__ ahora se está transformando en una empresa proveedora que ofrece diversas soluciones que hacen la vida más fácil, no sólo a los consumidores, sino que también amplía el acceso a ingresos para los socios y oportunidades de rápido crecimiento empresarial para los comerciantes, dijo Nadem. El cofundador de __gojek__, Kevin Aluwi, dijo en el mismo evento que este compromiso se fortaleció mediante el desarrollo de tres súper aplicaciones para usuarios, socios y comerciantes. Las aplicaciones para usuarios ahora brindan servicios para diversas necesidades, desde transporte, pedido de entradas para el cine, pedido de medicamentos hasta lavandería. Mientras tanto, en la solicitud de socio especial, dijo Kevin, ofrecen programas de asistencia financiera, préstamos para vivienda y vehículos, así como asistencia financiera para la Umrah. "Esa es nuestra parte para mejorar el bienestar de los socios conductores, así como alentarlos a brindar un mejor servicio a los clientes", dijo. Lea también: La expansión de __Gojek__ en la ASEAN se está ampliando, mientras tanto, para aplicaciones comerciales especiales, __Gojek__ facilita que los empresarios, especialmente las micro, pequeñas y medianas empresas __UMKM__ puedan aprender a desarrollar sus negocios y llegar a mercados a los que nunca antes se había llegado. Con una aplicación especial, los comerciantes pueden hacer varias cosas, como actualizar menús y crear promociones, afirmó. Actualmente, la aplicación __gojek__ ha sido descargada por más de un millón de usuarios, con más de un millón de socios conductores, casi. socios comerciales, y . Proveedor de servicios en el sudeste asiático. nuevo logo En esa ocasión, __gojek__ también lanzó un nuevo logo que se decía que era un signo de la evolución de __gojek__. El logotipo, que anteriormente usaba un símbolo de conductor de motocicleta verd ...
# Sampel data hasil augmentasi:
#                                        cleaned_content         label  \
# 428  masalah ojek online belum juga tuntas hingga s...  Foreign News
# 272  Survei terhadap mayoritas pengguna yang tetap ...      Economic
# 504  uiux study case optimalisasi aplikasi __gojek_...       Opinion
# 640  Sejumlah netizen mengeluhkan adanya error pada...      Academic
# 249  survei mayoritas pengguna tetap pakai ojol mes...      Economic
# 582  uiux study case optimalisasi aplikasi __gojek_...       Opinion
# 606  bali dengan segala kelakuan wisatawan asingnya...      Academic
# 410  masalah ojek online belum juga tuntas hingga s...  Foreign News
# 7    asosiasi pengemudi transportasi daring garda i...    Local News
# 732  oleh bang adi bagi sr 42 tahun , seorang drive...      Academic
#
#      is_augmented
# 428          True
# 272          True
# 504          True
# 640          True
# 249          True
# 582          True
# 606         False
# 410          True
# 7           False
# 732          True
